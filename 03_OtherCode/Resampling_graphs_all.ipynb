# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Resampling graphs

# %%
# LR

axis = [0.012, 0.0168, 0.025, 0.05, 0.075, 0.1, 0.2, 0.5, 1.0]

# %%
rus = [0.752756,
0.752837,
0.752753,
0.752921,
0.752978,
0.752906,
0.752939,
0.752783,
0.752291]

ros = [0.752656,
0.752394,
0.752470,
0.752681,
0.752816,
0.752936,
0.752903,
0.752697,
0.752407]

smote = [0.752666,
0.752539,
0.752395,
0.752390,
0.752151,
0.752074,
0.751953,
0.751718,
0.751329]

# %%
#  plot ros, rus and smote on the same graph using axis as x-axis with the corresponding y-axis values. use seaborn. y-axis label is ROC AUC score, use different line patterns

plt.plot(axis, smote, label = 'SMOTE', linestyle = 'dashed', color = 'orange')
plt.plot(axis, rus, label = 'RUS', linestyle = 'dashdot', color = 'blue')
plt.plot(axis, ros, label = 'ROS', color = 'orangered')
plt.xlabel('Target Ratio (logarithmic scale)')
plt.ylabel('ROC AUC Score')
plt.legend()
sns.scatterplot(axis, smote, color = 'orange')
sns.scatterplot(axis, rus, color = 'blue')
sns.scatterplot(axis, ros, color = 'orangered')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# decision tree

# %%
ros=[0.740513,
0.736992,
0.737346,
0.728393,
0.733358,
0.740055,
0.728726,
0.735679,
0.734929]

smote = [0.738385,
0.734474,
0.736485,
0.736327,
0.729972,
0.730406,
0.716503,
0.718926,
0.718088]

rus = [0.740200,
0.740028,
0.734621,
0.745569,
0.742549,
0.741685,
0.742700,
0.739750,
0.729001]

# %%
plt.plot(axis, smote, label = 'SMOTE', linestyle = 'dashed', color = 'orange')
plt.plot(axis, rus, label = 'RUS', linestyle = 'dashdot', color = 'blue')
plt.plot(axis, ros, label = 'ROS', color = 'orangered')
plt.xlabel('Target Ratio')
plt.ylabel('ROC AUC Score')
plt.legend()
sns.scatterplot(axis, smote, color = 'orange')
sns.scatterplot(axis, rus, color = 'blue')
sns.scatterplot(axis, ros, color = 'orangered')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#  plot ros, rus and smote on the same graph using axis as x-axis with the corresponding y-axis values. use seaborn. y-axis label is ROC AUC score, use different line patterns. use logarithmic scale for x-axis

plt.plot(axis, smote, label = 'SMOTE', linestyle = 'dashed', color = 'orange')
plt.plot(axis, rus, label = 'RUS', linestyle = 'dashdot', color = 'blue')
plt.plot(axis, ros, label = 'ROS', color = 'orangered')
plt.xlabel('Target Ratio (logarithmic scale)')
plt.ylabel('ROC AUC Score')
plt.legend()
sns.scatterplot(axis, smote, color = 'orange')
sns.scatterplot(axis, rus, color = 'blue')
sns.scatterplot(axis, ros, color = 'orangered')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# RF

axis = [0.012, 0.025, 0.05, 0.1, 1.0]

ros = [0.800659,
0.802197,
0.802473,
0.802214,
0.793610]

smote = [0.799941,
0.796907,
0.795364,
0.794364,
0.782360]

rus = [0.800362,
0.800850,
0.802133,
0.801893,
0.800589]

plt.plot(axis, smote, label = 'SMOTE', linestyle = 'dashed', color = 'orange')
plt.plot(axis, rus, label = 'RUS', linestyle = 'dashdot', color = 'blue')
plt.plot(axis, ros, label = 'ROS', color = 'orangered')
plt.xlabel('Target Ratio (logarithmic scale)')
plt.ylabel('ROC AUC Score')
plt.legend()
sns.scatterplot(axis, smote, color = 'orange')
sns.scatterplot(axis, rus, color = 'blue')
sns.scatterplot(axis, ros, color = 'orangered')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#XGB

ros = [0.816765,
0.815402,
0.815725,
0.815330,
0.813545]

smote = [0.816202,
0.806575,
0.795206,
0.787050,
0.775051]

rus = [0.817152,
0.816790,
0.816030,
0.814263,
0.808985]

plt.plot(axis, smote, label = 'SMOTE', linestyle = 'dashed', color = 'orange')
plt.plot(axis, rus, label = 'RUS', linestyle = 'dashdot', color = 'blue')
plt.plot(axis, ros, label = 'ROS', color = 'orangered')
plt.xlabel('Target Ratio (logarithmic scale)')
plt.ylabel('ROC AUC Score')
plt.legend()
sns.scatterplot(axis, smote, color = 'orange')
sns.scatterplot(axis, rus, color = 'blue')
sns.scatterplot(axis, ros, color = 'orangered')
plt.xscale('log')
plt.show()
# Out:
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\tomta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
